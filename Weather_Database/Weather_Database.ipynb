# %%
import pandas as pd
import numpy as np
from citipy import citipy
from datetime import datetime
import requests

# %%
from weather_config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fb15583c337ed0493d5bc80802cc4b9b

# %%
# Create a set of random laitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lat and longs to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination 
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities: 
        cities.append(city)
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters
record_count = 1
set_count = 1 

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | enid
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | fort nelson
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | pringsewu
# Processing Record 9 of Set 1 | san cristobal
# Processing Record 10 of Set 1 | riosucio
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | furth im wald
# Processing Record 13 of Set 1 | leningradskiy
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | garden city
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | balkanabat
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | aklavik
# Processing Record 24 of Set 1 | constitucion
# Processing Record 25 of Set 1 | kupang
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | flinders
# Processing Record 29 of Set 1 | saint-leu
# Processing Record 30 of Set 1 | san patricio
# Processing Record 31 of Set 1 | saint-augustin
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | kuryk
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | stevenage
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | tuatapere
# Processing Record 39 of Set 1 | guayaramerin
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | nabire
# Processing Record 42 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | charters towers
# Processing Record 48 of Set 1 | ciudad bolivar
# Processing Record 49 of Set 1 | luau
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | jian
# Processing Record 5 of Set 2 | saint-joseph
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | biak
# Processing Record 9 of Set 2 | upata
# Processing Record 10 of Set 2 | saint-pierre
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | innisfail
# Processing Record 13 of Set 2 | rafai
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | brae
# Processing Record 16 of Set 2 | bathsheba
# Processing Record 17 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | cuitzeo
# Processing Record 20 of Set 2 | nivala
# Processing Record 21 of Set 2 | cine
# Processing Record 22 of Set 2 | palaia fokaia
# Processing Record 23 of Set 2 | najran
# Processing Record 24 of Set 2 | kaeo
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | bonavista
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | chabahar
# Processing Record 29 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | pakxan
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | inhambane
# Processing Record 37 of Set 2 | mujiayingzi
# Processing Record 38 of Set 2 | tezu
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | celestun
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | kharp
# Processing Record 44 of Set 2 | san vicente de canete
# Processing Record 45 of Set 2 | buin
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | vila velha
# Processing Record 49 of Set 2 | sao joao da barra
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | beringovskiy
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | suez
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | gohana
# Processing Record 10 of Set 3 | krasnoselkup
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | bitam
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | diamantina
# Processing Record 17 of Set 3 | sorland
# Processing Record 18 of Set 3 | buchanan
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | kutum
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | paamiut
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | high level
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | seoul
# Processing Record 30 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | sidi ali
# Processing Record 33 of Set 3 | chegdomyn
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | pangnirtung
# Processing Record 36 of Set 3 | bilibino
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | zhigalovo
# Processing Record 40 of Set 3 | itajuba
# Processing Record 41 of Set 3 | sao francisco
# Processing Record 42 of Set 3 | kolosovka
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | cockburn town
# Processing Record 45 of Set 3 | alugan
# Processing Record 46 of Set 3 | nome
# Processing Record 47 of Set 3 | omsukchan
# Processing Record 48 of Set 3 | ambovombe
# Processing Record 49 of Set 3 | tuy hoa
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | norman wells
# Processing Record 2 of Set 4 | malakal
# Processing Record 3 of Set 4 | mankera
# Processing Record 4 of Set 4 | arlit
# Processing Record 5 of Set 4 | bireun
# Processing Record 6 of Set 4 | janakpur
# Processing Record 7 of Set 4 | bosaso
# Processing Record 8 of Set 4 | woodstock
# Processing Record 9 of Set 4 | hirara
# Processing Record 10 of Set 4 | tevaitoa
# Processing Record 11 of Set 4 | altay
# Processing Record 12 of Set 4 | fethiye
# Processing Record 13 of Set 4 | drexel heights
# Processing Record 14 of Set 4 | uva
# Processing Record 15 of Set 4 | caucaia
# Processing Record 16 of Set 4 | baykit
# Processing Record 17 of Set 4 | bluff
# Processing Record 18 of Set 4 | bulgan
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | aksu
# Processing Record 21 of Set 4 | uray
# Processing Record 22 of Set 4 | bonito
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | hambantota
# Processing Record 25 of Set 4 | qaqortoq
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | chiredzi
# Processing Record 28 of Set 4 | bandarbeyla
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | xghajra
# City not found. Skipping...
# Processing Record 34 of Set 4 | eirunepe
# Processing Record 35 of Set 4 | oriximina
# Processing Record 36 of Set 4 | pangai
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | shaowu
# Processing Record 39 of Set 4 | marovoay
# Processing Record 40 of Set 4 | bulolo
# Processing Record 41 of Set 4 | poya
# Processing Record 42 of Set 4 | husavik
# Processing Record 43 of Set 4 | mayo
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | hami
# Processing Record 46 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 4 | huarmey
# Processing Record 48 of Set 4 | guasave
# Processing Record 49 of Set 4 | iquique
# Processing Record 50 of Set 4 | abu kamal
# Processing Record 1 of Set 5 | meihekou
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | hailar
# Processing Record 4 of Set 5 | oktyabrsk
# Processing Record 5 of Set 5 | tahe
# Processing Record 6 of Set 5 | namatanai
# Processing Record 7 of Set 5 | adrar
# Processing Record 8 of Set 5 | goderich
# Processing Record 9 of Set 5 | narrabri
# Processing Record 10 of Set 5 | basoko
# Processing Record 11 of Set 5 | otradnoye
# Processing Record 12 of Set 5 | palmer
# Processing Record 13 of Set 5 | north platte
# Processing Record 14 of Set 5 | dawei
# Processing Record 15 of Set 5 | savantvadi
# Processing Record 16 of Set 5 | ocos
# Processing Record 17 of Set 5 | puerto padre
# Processing Record 18 of Set 5 | kerman
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | wadi musa
# Processing Record 21 of Set 5 | dikson
# Processing Record 22 of Set 5 | flin flon
# Processing Record 23 of Set 5 | moree
# Processing Record 24 of Set 5 | coquimbo
# Processing Record 25 of Set 5 | mogok
# Processing Record 26 of Set 5 | lasa
# Processing Record 27 of Set 5 | aswan
# Processing Record 28 of Set 5 | solnechnyy
# Processing Record 29 of Set 5 | tuktoyaktuk
# Processing Record 30 of Set 5 | ouargaye
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | kardailovo
# Processing Record 33 of Set 5 | ayr
# Processing Record 34 of Set 5 | hanyang
# Processing Record 35 of Set 5 | boffa
# Processing Record 36 of Set 5 | fernley
# Processing Record 37 of Set 5 | cody
# Processing Record 38 of Set 5 | gorgan
# Processing Record 39 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 40 of Set 5 | cidreira
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | owo
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 5 | zhuhai
# Processing Record 48 of Set 5 | at-bashi
# Processing Record 49 of Set 5 | ambo
# Processing Record 50 of Set 5 | vredendal
# Processing Record 1 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 6 | smolenka
# Processing Record 3 of Set 6 | soubre
# Processing Record 4 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 6 | riaba
# City not found. Skipping...
# Processing Record 6 of Set 6 | paragominas
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | vao
# Processing Record 9 of Set 6 | kivsharivka
# Processing Record 10 of Set 6 | khadyzhensk
# Processing Record 11 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 6 | cartagena
# Processing Record 13 of Set 6 | port alfred
# Processing Record 14 of Set 6 | qaanaaq
# Processing Record 15 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 6 | vidalia
# Processing Record 17 of Set 6 | poum
# Processing Record 18 of Set 6 | pyinmana
# Processing Record 19 of Set 6 | dickinson
# Processing Record 20 of Set 6 | togur
# Processing Record 21 of Set 6 | matamoros
# Processing Record 22 of Set 6 | baghdad
# Processing Record 23 of Set 6 | anadyr
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | ponta do sol
# Processing Record 27 of Set 6 | moose factory
# Processing Record 28 of Set 6 | bloemhof
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | warri
# Processing Record 31 of Set 6 | chumikan
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | severka
# Processing Record 34 of Set 6 | foumbot
# Processing Record 35 of Set 6 | kosh-agach
# Processing Record 36 of Set 6 | port-gentil
# Processing Record 37 of Set 6 | beasain
# Processing Record 38 of Set 6 | broken hill
# Processing Record 39 of Set 6 | diphu
# Processing Record 40 of Set 6 | baturaja
# Processing Record 41 of Set 6 | uk
# City not found. Skipping...
# Processing Record 42 of Set 6 | ler
# Processing Record 43 of Set 6 | korla
# Processing Record 44 of Set 6 | abilene
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | mosquera
# Processing Record 47 of Set 6 | xai-xai
# Processing Record 48 of Set 6 | bengkulu
# Processing Record 49 of Set 6 | chernyshevskiy
# Processing Record 50 of Set 6 | korcula
# Processing Record 1 of Set 7 | alto araguaia
# Processing Record 2 of Set 7 | duz
# City not found. Skipping...
# Processing Record 3 of Set 7 | tuscaloosa
# Processing Record 4 of Set 7 | thunder bay
# Processing Record 5 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 7 | sitges
# Processing Record 7 of Set 7 | sioux lookout
# Processing Record 8 of Set 7 | atambua
# Processing Record 9 of Set 7 | agirish
# Processing Record 10 of Set 7 | kahului
# Processing Record 11 of Set 7 | girau do ponciano
# Processing Record 12 of Set 7 | lufilufi
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 7 | muyezerskiy
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | mogadishu
# Processing Record 20 of Set 7 | tutoia
# Processing Record 21 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 7 | strezhevoy
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | george
# Processing Record 26 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 7 | ketchikan
# Processing Record 28 of Set 7 | chiradzulu
# Processing Record 29 of Set 7 | klyuchi
# Processing Record 30 of Set 7 | ahipara
# Processing Record 31 of Set 7 | yei
# Processing Record 32 of Set 7 | faanui
# Processing Record 33 of Set 7 | kochevo
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | akureyri
# Processing Record 36 of Set 7 | strathmore
# Processing Record 37 of Set 7 | grand-lahou
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | aykhal
# Processing Record 40 of Set 7 | delijan
# Processing Record 41 of Set 7 | amga
# Processing Record 42 of Set 7 | san juan
# Processing Record 43 of Set 7 | erenhot
# Processing Record 44 of Set 7 | kulachi
# Processing Record 45 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 7 | salalah
# Processing Record 47 of Set 7 | vaitape
# Processing Record 48 of Set 7 | mende
# Processing Record 49 of Set 7 | tucurui
# Processing Record 50 of Set 7 | katherine
# Processing Record 1 of Set 8 | marawi
# Processing Record 2 of Set 8 | toora-khem
# Processing Record 3 of Set 8 | balkhash
# Processing Record 4 of Set 8 | roma
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | komsomolskiy
# Processing Record 7 of Set 8 | yefimovskiy
# City not found. Skipping...
# Processing Record 8 of Set 8 | pathanamthitta
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | umtata
# Processing Record 11 of Set 8 | robertson
# Processing Record 12 of Set 8 | kirakira
# Processing Record 13 of Set 8 | chuy
# Processing Record 14 of Set 8 | merauke
# Processing Record 15 of Set 8 | tasiilaq
# Processing Record 16 of Set 8 | sola
# Processing Record 17 of Set 8 | timizart
# Processing Record 18 of Set 8 | tilichiki
# Processing Record 19 of Set 8 | murray bridge
# Processing Record 20 of Set 8 | harlingen
# Processing Record 21 of Set 8 | hithadhoo
# Processing Record 22 of Set 8 | antalaha
# Processing Record 23 of Set 8 | williamsport
# Processing Record 24 of Set 8 | araguatins
# City not found. Skipping...
# Processing Record 25 of Set 8 | rockport
# Processing Record 26 of Set 8 | aleksandriya
# Processing Record 27 of Set 8 | byron bay
# Processing Record 28 of Set 8 | port blair
# Processing Record 29 of Set 8 | khasan
# Processing Record 30 of Set 8 | sorong
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | longyearbyen
# Processing Record 33 of Set 8 | smithers
# Processing Record 34 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | marsa matruh
# Processing Record 37 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 38 of Set 8 | skjervoy
# Processing Record 39 of Set 8 | santa cruz
# Processing Record 40 of Set 8 | gat
# Processing Record 41 of Set 8 | kochi
# Processing Record 42 of Set 8 | sao felix do xingu
# Processing Record 43 of Set 8 | bereda
# Processing Record 44 of Set 8 | gdov
# Processing Record 45 of Set 8 | fatehpur
# Processing Record 46 of Set 8 | dondo
# Processing Record 47 of Set 8 | nanakuli
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | ust-barguzin
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | lumphat
# Processing Record 2 of Set 9 | ipixuna
# Processing Record 3 of Set 9 | ascension
# Processing Record 4 of Set 9 | fortuna
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | batagay-alyta
# Processing Record 7 of Set 9 | kaihua
# Processing Record 8 of Set 9 | cap malheureux
# Processing Record 9 of Set 9 | mao
# Processing Record 10 of Set 9 | monteprandone
# Processing Record 11 of Set 9 | dunedin
# Processing Record 12 of Set 9 | sur
# Processing Record 13 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 14 of Set 9 | gracac
# Processing Record 15 of Set 9 | fayaoue
# Processing Record 16 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 9 | teguise
# Processing Record 18 of Set 9 | shimoda
# Processing Record 19 of Set 9 | alice springs
# Processing Record 20 of Set 9 | san bartolome de tirajana
# Processing Record 21 of Set 9 | dingle
# Processing Record 22 of Set 9 | nokaneng
# Processing Record 23 of Set 9 | kloulklubed
# Processing Record 24 of Set 9 | roald
# Processing Record 25 of Set 9 | toamasina
# Processing Record 26 of Set 9 | bubaque
# Processing Record 27 of Set 9 | aquiraz
# Processing Record 28 of Set 9 | elko
# Processing Record 29 of Set 9 | tanjong malim
# City not found. Skipping...
# Processing Record 30 of Set 9 | nhulunbuy
# Processing Record 31 of Set 9 | saa
# Processing Record 32 of Set 9 | bambanglipuro
# Processing Record 33 of Set 9 | puerto madryn
# Processing Record 34 of Set 9 | mackenzie
# Processing Record 35 of Set 9 | bogovarovo
# Processing Record 36 of Set 9 | yar-sale
# Processing Record 37 of Set 9 | belyy yar
# Processing Record 38 of Set 9 | boali
# Processing Record 39 of Set 9 | emerald
# Processing Record 40 of Set 9 | puerto colombia
# Processing Record 41 of Set 9 | aloleng
# Processing Record 42 of Set 9 | reyes
# Processing Record 43 of Set 9 | meulaboh
# Processing Record 44 of Set 9 | quesnel
# Processing Record 45 of Set 9 | mehamn
# Processing Record 46 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 9 | inta
# Processing Record 48 of Set 9 | los llanos de aridane
# Processing Record 49 of Set 9 | fairbanks
# Processing Record 50 of Set 9 | zhezkazgan
# Processing Record 1 of Set 10 | datong
# Processing Record 2 of Set 10 | tual
# Processing Record 3 of Set 10 | itarema
# Processing Record 4 of Set 10 | avila
# Processing Record 5 of Set 10 | la argentina
# Processing Record 6 of Set 10 | abu dhabi
# Processing Record 7 of Set 10 | ayan
# Processing Record 8 of Set 10 | dosso
# Processing Record 9 of Set 10 | riyadh
# Processing Record 10 of Set 10 | acajutla
# Processing Record 11 of Set 10 | chiriqui grande
# Processing Record 12 of Set 10 | saskylakh
# Processing Record 13 of Set 10 | sept-iles
# Processing Record 14 of Set 10 | van
# Processing Record 15 of Set 10 | thap than
# Processing Record 16 of Set 10 | surgut
# Processing Record 17 of Set 10 | tambo
# Processing Record 18 of Set 10 | pevek
# Processing Record 19 of Set 10 | yenagoa
# Processing Record 20 of Set 10 | kurayoshi
# Processing Record 21 of Set 10 | balsas
# Processing Record 22 of Set 10 | shihezi
# Processing Record 23 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | romitan
# Processing Record 25 of Set 10 | dan khun thot
# Processing Record 26 of Set 10 | iqaluit
# Processing Record 27 of Set 10 | tanout
# Processing Record 28 of Set 10 | selma
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | acapulco
# Processing Record 32 of Set 10 | the valley
# Processing Record 33 of Set 10 | port macquarie
# Processing Record 34 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 10 | manacapuru
# Processing Record 36 of Set 10 | itaituba
# Processing Record 37 of Set 10 | alvaraes
# Processing Record 38 of Set 10 | shieli
# Processing Record 39 of Set 10 | netivot
# Processing Record 40 of Set 10 | alegrete
# Processing Record 41 of Set 10 | christchurch
# Processing Record 42 of Set 10 | santa maria
# Processing Record 43 of Set 10 | puerto carreno
# Processing Record 44 of Set 10 | kanniyakumari
# Processing Record 45 of Set 10 | hay river
# Processing Record 46 of Set 10 | satuk
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | zdvinsk
# Processing Record 49 of Set 10 | lorengau
# Processing Record 50 of Set 10 | ponta delgada
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | jumla
# Processing Record 3 of Set 11 | pacocha
# Processing Record 4 of Set 11 | berea
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | shingu
# Processing Record 7 of Set 11 | elizabethton
# Processing Record 8 of Set 11 | port hedland
# Processing Record 9 of Set 11 | monrovia
# Processing Record 10 of Set 11 | lampa
# Processing Record 11 of Set 11 | ardea
# Processing Record 12 of Set 11 | devils lake
# Processing Record 13 of Set 11 | hualmay
# Processing Record 14 of Set 11 | canico
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | kirovskiy
# Processing Record 17 of Set 11 | sao filipe
# Processing Record 18 of Set 11 | nongpoh
# Processing Record 19 of Set 11 | bitung
# Processing Record 20 of Set 11 | zeya
# Processing Record 21 of Set 11 | amberley
# Processing Record 22 of Set 11 | mizdah
# Processing Record 23 of Set 11 | ternate
# Processing Record 24 of Set 11 | gazojak
# Processing Record 25 of Set 11 | sri aman
# Processing Record 26 of Set 11 | evensk
# Processing Record 27 of Set 11 | carlsbad
# Processing Record 28 of Set 11 | nelson bay
# Processing Record 29 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 30 of Set 11 | presidencia roque saenz pena
# Processing Record 31 of Set 11 | suihua
# Processing Record 32 of Set 11 | saravan
# Processing Record 33 of Set 11 | kerema
# Processing Record 34 of Set 11 | firminy
# Processing Record 35 of Set 11 | hofn
# Processing Record 36 of Set 11 | petatlan
# Processing Record 37 of Set 11 | luderitz
# Processing Record 38 of Set 11 | karpathos
# Processing Record 39 of Set 11 | aden
# Processing Record 40 of Set 11 | chaman
# Processing Record 41 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 11 | korhogo
# Processing Record 43 of Set 11 | annau
# Processing Record 44 of Set 11 | valera
# Processing Record 45 of Set 11 | moranbah
# Processing Record 46 of Set 11 | treinta y tres
# Processing Record 47 of Set 11 | marshall
# Processing Record 48 of Set 11 | sungaipenuh
# Processing Record 49 of Set 11 | kirkuk
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 12 | avdon
# Processing Record 3 of Set 12 | tulsa
# Processing Record 4 of Set 12 | nerchinsk
# Processing Record 5 of Set 12 | dombarovskiy
# Processing Record 6 of Set 12 | king city
# Processing Record 7 of Set 12 | vardo
# Processing Record 8 of Set 12 | yeppoon
# Processing Record 9 of Set 12 | nara
# Processing Record 10 of Set 12 | ileza
# Processing Record 11 of Set 12 | singaparna
# Processing Record 12 of Set 12 | tshikapa
# Processing Record 13 of Set 12 | shenjiamen
# Processing Record 14 of Set 12 | centerville
# Processing Record 15 of Set 12 | bonthe
# Processing Record 16 of Set 12 | yambio
# Processing Record 17 of Set 12 | sulangan
# Processing Record 18 of Set 12 | ostrovnoy
# Processing Record 19 of Set 12 | srinivaspur
# Processing Record 20 of Set 12 | nenjiang
# Processing Record 21 of Set 12 | sakaiminato
# Processing Record 22 of Set 12 | pemba
# Processing Record 23 of Set 12 | carauari
# Processing Record 24 of Set 12 | marsala
# Processing Record 25 of Set 12 | mizan teferi
# Processing Record 26 of Set 12 | lahat
# Processing Record 27 of Set 12 | acari
# Processing Record 28 of Set 12 | kristianstad
# Processing Record 29 of Set 12 | xadani
# City not found. Skipping...
# Processing Record 30 of Set 12 | salinopolis
# Processing Record 31 of Set 12 | calabozo
# Processing Record 32 of Set 12 | kodino
# Processing Record 33 of Set 12 | mount isa
# Processing Record 34 of Set 12 | roswell
# Processing Record 35 of Set 12 | shimanovsk
# Processing Record 36 of Set 12 | walvis bay
# Processing Record 37 of Set 12 | changping
# Processing Record 38 of Set 12 | garowe
# Processing Record 39 of Set 12 | sibolga
# Processing Record 40 of Set 12 | ambilobe
# Processing Record 41 of Set 12 | karratha
# Processing Record 42 of Set 12 | marsaxlokk
# Processing Record 43 of Set 12 | nizhnevartovsk
# Processing Record 44 of Set 12 | nemuro
# Processing Record 45 of Set 12 | ajdabiya
# Processing Record 46 of Set 12 | kishtwar
# Processing Record 47 of Set 12 | beli potok
# Processing Record 48 of Set 12 | along
# Processing Record 49 of Set 12 | ares
# Processing Record 50 of Set 12 | kautokeino
# Processing Record 1 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 2 of Set 13 | puri
# Processing Record 3 of Set 13 | ammon
# Processing Record 4 of Set 13 | diamantino
# Processing Record 5 of Set 13 | ugoofaaru
# Processing Record 6 of Set 13 | burnie
# Processing Record 7 of Set 13 | cheremukhovo
# Processing Record 8 of Set 13 | polunochnoye
# Processing Record 9 of Set 13 | zhuozhou
# City not found. Skipping...
# Processing Record 10 of Set 13 | bairiki
# Processing Record 11 of Set 13 | tabuk
# Processing Record 12 of Set 13 | lagunas
# Processing Record 13 of Set 13 | brooks
# Processing Record 14 of Set 13 | berlevag
# Processing Record 15 of Set 13 | prince rupert
# Processing Record 16 of Set 13 | olsberg
# Processing Record 17 of Set 13 | hokitika
# Processing Record 18 of Set 13 | hamilton
# Processing Record 19 of Set 13 | ixtapa
# Processing Record 20 of Set 13 | kramat
# Processing Record 21 of Set 13 | lagos
# Processing Record 22 of Set 13 | livingston
# Processing Record 23 of Set 13 | avera
# Processing Record 24 of Set 13 | gao
# Processing Record 25 of Set 13 | oranjestad
# Processing Record 26 of Set 13 | kabansk
# Processing Record 27 of Set 13 | simplicio mendes
# Processing Record 28 of Set 13 | kumba
# Processing Record 29 of Set 13 | belaya gora
# Processing Record 30 of Set 13 | vila
# Processing Record 31 of Set 13 | marzuq
# Processing Record 32 of Set 13 | nizamabad
# Processing Record 33 of Set 13 | palmerston
# Processing Record 34 of Set 13 | neiafu
# Processing Record 35 of Set 13 | new scone
# Processing Record 36 of Set 13 | sweetwater
# Processing Record 37 of Set 13 | calama
# Processing Record 38 of Set 13 | wodonga
# Processing Record 39 of Set 13 | jalu
# Processing Record 40 of Set 13 | mackay
# Processing Record 41 of Set 13 | sisimiut
# Processing Record 42 of Set 13 | castlegar
# Processing Record 43 of Set 13 | surt
# Processing Record 44 of Set 13 | keflavik
# Processing Record 45 of Set 13 | port angeles
# Processing Record 46 of Set 13 | chacabuco
# Processing Record 47 of Set 13 | chapais
# Processing Record 48 of Set 13 | trapani
# Processing Record 49 of Set 13 | port moresby
# Processing Record 50 of Set 13 | basco
# Processing Record 1 of Set 14 | lahaina
# Processing Record 2 of Set 14 | nizhniy baskunchak
# Processing Record 3 of Set 14 | woodward
# Processing Record 4 of Set 14 | labuan
# Processing Record 5 of Set 14 | gulu
# Processing Record 6 of Set 14 | xining
# Processing Record 7 of Set 14 | maceio
# Processing Record 8 of Set 14 | qandala
# Processing Record 9 of Set 14 | dicabisagan
# Processing Record 10 of Set 14 | peleduy
# Processing Record 11 of Set 14 | kulhudhuffushi
# Processing Record 12 of Set 14 | kashi
# Processing Record 13 of Set 14 | jacareacanga
# Processing Record 14 of Set 14 | zyryanka
# Processing Record 15 of Set 14 | tessalit
# Processing Record 16 of Set 14 | sabang
# Processing Record 17 of Set 14 | ebano
# City not found. Skipping...
# Processing Record 18 of Set 14 | ambikapur
# Processing Record 19 of Set 14 | mandalgovi
# Processing Record 20 of Set 14 | goba
# Processing Record 21 of Set 14 | dakar
# Processing Record 22 of Set 14 | isabela
# Processing Record 23 of Set 14 | general roca
# Processing Record 24 of Set 14 | clyde river
# Processing Record 25 of Set 14 | sayyan
# Processing Record 26 of Set 14 | ilulissat
# Processing Record 27 of Set 14 | grimshaw
# Processing Record 28 of Set 14 | jacqueville
# Processing Record 29 of Set 14 | daru
# Processing Record 30 of Set 14 | nova olinda do norte
# Processing Record 31 of Set 14 | komatipoort
# Processing Record 32 of Set 14 | betanzos
# Processing Record 33 of Set 14 | okha
# Processing Record 34 of Set 14 | ubinskoye
# Processing Record 35 of Set 14 | terme
# Processing Record 36 of Set 14 | bontang
# Processing Record 37 of Set 14 | havelock
# Processing Record 38 of Set 14 | chapada dos guimaraes
# Processing Record 39 of Set 14 | skibbereen
# Processing Record 40 of Set 14 | kyren
# Processing Record 41 of Set 14 | okhotsk
# Processing Record 42 of Set 14 | jinchang
# Processing Record 43 of Set 14 | abu zabad
# Processing Record 44 of Set 14 | tailai
# Processing Record 45 of Set 14 | mitsamiouli
# Processing Record 46 of Set 14 | tolaga bay
# Processing Record 47 of Set 14 | cascais
# Processing Record 48 of Set 14 | shangqiu
# Processing Record 49 of Set 14 | mehran
# Processing Record 50 of Set 14 | baruun-urt
# Processing Record 1 of Set 15 | nagar karnul
# Processing Record 2 of Set 15 | san pedro de cajas
# Processing Record 3 of Set 15 | quang ngai
# Processing Record 4 of Set 15 | bowen
# Processing Record 5 of Set 15 | mezen
# Processing Record 6 of Set 15 | nalut
# Processing Record 7 of Set 15 | yangambi
# Processing Record 8 of Set 15 | shaoyang
# Processing Record 9 of Set 15 | yumen
# Processing Record 10 of Set 15 | pryozerne
# Processing Record 11 of Set 15 | ndele
# Processing Record 12 of Set 15 | lamu
# Processing Record 13 of Set 15 | asau
# Processing Record 14 of Set 15 | luganville
# Processing Record 15 of Set 15 | grand gaube
# Processing Record 16 of Set 15 | santa marta
# Processing Record 17 of Set 15 | boguchany
# Processing Record 18 of Set 15 | labuhan
# Processing Record 19 of Set 15 | bakani
# Processing Record 20 of Set 15 | rosetta
# Processing Record 21 of Set 15 | arrecife
# Processing Record 22 of Set 15 | hue
# Processing Record 23 of Set 15 | mareeba
# Processing Record 24 of Set 15 | harda
# Processing Record 25 of Set 15 | port augusta
# Processing Record 26 of Set 15 | mulege
# Processing Record 27 of Set 15 | samarai
# Processing Record 28 of Set 15 | kangaba
# Processing Record 29 of Set 15 | peniche
# Processing Record 30 of Set 15 | crotone
# Processing Record 31 of Set 15 | lomovka
# Processing Record 32 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 15 | raga
# Processing Record 34 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 15 | shagonar
# Processing Record 37 of Set 15 | cruzilia
# Processing Record 38 of Set 15 | huangchuan
# Processing Record 39 of Set 15 | emirdag
# Processing Record 40 of Set 15 | taitung
# Processing Record 41 of Set 15 | pesaro
# Processing Record 42 of Set 15 | kerouane
# Processing Record 43 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 15 | bentiu
# Processing Record 45 of Set 15 | sonamukhi
# Processing Record 46 of Set 15 | kargasok
# Processing Record 47 of Set 15 | gamboma
# Processing Record 48 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 15 | chapleau
# Processing Record 50 of Set 15 | chelmno
# Processing Record 1 of Set 16 | kaitangata
# Processing Record 2 of Set 16 | sibenik
# Processing Record 3 of Set 16 | naze
# Processing Record 4 of Set 16 | tsiroanomandidy
# Processing Record 5 of Set 16 | valky
# Processing Record 6 of Set 16 | rocha
# Processing Record 7 of Set 16 | dudinka
# Processing Record 8 of Set 16 | moerai
# Processing Record 9 of Set 16 | carndonagh
# Processing Record 10 of Set 16 | fenoarivo atsinanana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             Enid      US  36.40  -97.88     66.20       100          90
# 1  Bambous Virieux      MU -20.34   57.76     75.20        69          40
# 2      Fort Nelson      CA  58.81 -122.70     15.80        85          90
# 3      New Norfolk      AU -42.78  147.06     55.99        63          99
# 4       Chokurdakh      RU  70.63  147.92    -14.35        90          92
# 5          Mataura      NZ -46.19  168.86     37.98        95           2
# 6        Pringsewu      ID  -5.36  104.97     74.41        91         100
# 7    San Cristobal      VE   7.77  -72.22     82.40        78          40
# 8         Riosucio      CO   5.42  -75.70     69.80        88          75
# 9         Khatanga      RU  71.97  102.50     20.21        97         100
#
#    Wind Speed Current Description
# 0       19.46     overcast clouds
# 1       11.41    scattered clouds
# 2        2.24     overcast clouds
# 3        1.01     overcast clouds
# 4        2.89     overcast clouds
# 5        2.06           clear sky
# 6        3.33     overcast clouds
# 7        2.24                 fog
# 8        2.24                 fog
# 9       17.13          light snow

# %%
# Create the output file (CSV).
output_data_file = "/Users/tylerengalla/Desktop/Data_Bootcamp/Analysis_Projects/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
